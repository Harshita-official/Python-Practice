# %%
import pandas as pd

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.5.0-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\harsh\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\harsh\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------------- -------------------------- 3.4/9.9 MB 22.1 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 26.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 23.4 MB/s  0:00:00
# Downloading numpy-2.5.0-cp314-cp314-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------------------------- -------------- 7.9/12.6 MB 40.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 30.2 MB/s  0:00:00
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: tzdata, numpy, pandas
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed numpy-2.5.0 pandas-3.0.3 tzdata-2026.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Pandas is a Python library used for data analysis, data cleaning, and data manipulation.
import pandas as pd

# %%
import numpy as np

# %%
data=np.array([[1,4],[2,5],[4,6]])
data
# Out:
# array([[1, 4],
#        [2, 5],
#        [4, 6]])

# %%
df=pd.DataFrame(data,index=['row1','row2','row3'],columns=['col1','col2'])
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     4     6

# %%
data1=np.array([[1,2,3,4],[2,3,4,5],[3,4,5,6],[4,5,6,7],[5,6,7,8]])
data1
# Out:
# array([[1, 2, 3, 4],
#        [2, 3, 4, 5],
#        [3, 4, 5, 6],
#        [4, 5, 6, 7],
#        [5, 6, 7, 8]])

# %%
df=pd.DataFrame(data1,index=['row1','row2','row3','row4','row5'],columns=['col1','col2','col3','col4'])
df
# Out:
#       col1  col2  col3  col4
# row1     1     2     3     4
# row2     2     3     4     5
# row3     3     4     5     6
# row4     4     5     6     7
# row5     5     6     7     8

# %%
states=['Maharashtra','Delhi','Punjab','Hariyana']
population=[125000000, 33000000, 30000000, 29000000]

# %%
dict_status={'States':states,'Population':population}
dict_status
# Out:
# {'States': ['Maharashtra', 'Delhi', 'Punjab', 'Hariyana'],
#  'Population': [125000000, 33000000, 30000000, 29000000]}

# %%
India=pd.DataFrame(dict_status)
India
# Out:
#         States  Population
# 0  Maharashtra   125000000
# 1        Delhi    33000000
# 2       Punjab    30000000
# 3     Hariyana    29000000

# %%
import pandas as pd

# %%
# Raw file import into Code using drag and drop 
df=pd.read_csv("D:/python/StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
# Raw file import using direct copy path
df1=pd.read_csv("https://raw.githubusercontent.com/Harshita-official/Python-for-Data-Science/refs/heads/main/python-for-data-science-main/02.Intro%20to%20Pandas/StudentsPerformance.csv")
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
import requests
import pandas as pd
from io import StringIO
from bs4 import BeautifulSoup

# %%
# !pip install requests beautifulsoup4 lxml
# Out:
# Collecting requests
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.15.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting lxml
#   Downloading lxml-6.1.1-cp314-cp314-win_amd64.whl.metadata (3.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.8-cp314-cp314-win_amd64.whl.metadata (42 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting urllib3<3,>=1.26 (from requests)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests)
#   Downloading certifi-2026.6.17-py3-none-any.whl.metadata (2.5 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4)
#   Downloading soupsieve-2.8.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\harsh\AppData\Roaming\Python\Python314\site-packages (from beautifulsoup4) (4.15.0)
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading charset_normalizer-3.4.8-cp314-cp314-win_amd64.whl (162 kB)
# Downloading idna-3.18-py3-none-any.whl (65 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading beautifulsoup4-4.15.0-py3-none-any.whl (109 kB)
# Downloading lxml-6.1.1-cp314-cp314-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.1 MB 2.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/4.1 MB 3.0 MB/s eta 0:00:02
#    ------------------ --------------------- 1.8/4.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------- -------------- 2.6/4.1 MB 3.1 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 3.1 MB/s  0:00:01
# Downloading certifi-2026.6.17-py3-none-any.whl (133 kB)
# Downloading soupsieve-2.8.4-py3-none-any.whl (37 kB)
# Installing collected packages: urllib3, soupsieve, lxml, idna, charset_normalizer, certifi, requests, beautifulsoup4
#
#    ---------------------------------------- 0/8 [urllib3]
#    ---------------------------------------- 0/8 [urllib3]
#    ---------------------------------------- 0/8 [urllib3]
#    ---------------------------------------- 0/8 [urllib3]
#    ---------------------------------------- 0/8 [urllib3]
#    ---------------------------------------- 0/8 [urllib3]
#    ----- ---------------------------------- 1/8 [soupsieve]
#    ----- ---------------------------------- 1/8 [soupsieve]
#    ---------- ----------------------------- 2/8 [lxml]
#    ---------- ----------------------------- 2/8 [lxml]
#    ---------- ----------------------------- 2/8 [lxml]
#    ---------- ----------------------------- 2/8 [lxml]
#    ---------- ----------------------------- 2/8 [lxml]
#    ---------- ----------------------------- 2/8 [lxml]
#    ---------- ----------------------------- 2/8 [lxml]
#    --------------- ------------------------ 3/8 [idna]
#    --------------- ------------------------ 3/8 [idna]
#    --------------- ------------------------ 3/8 [idna]
#    -------------------- ------------------- 4/8 [charset_normalizer]
#    -------------------- ------------------- 4/8 [charset_normalizer]
#    -------------------- ------------------- 4/8 [charset_normalizer]
#    ------------------------------ --------- 6/8 [requests]
#    ------------------------------ --------- 6/8 [requests]
#    ------------------------------ --------- 6/8 [requests]
#    ------------------------------ --------- 6/8 [requests]
#    ----------------------------------- ---- 7/8 [beautifulsoup4]
#    ----------------------------------- ---- 7/8 [beautifulsoup4]
#    ----------------------------------- ---- 7/8 [beautifulsoup4]
#    ---------------------------------------- 8/8 [beautifulsoup4]
#
# Successfully installed beautifulsoup4-4.15.0 certifi-2026.6.17 charset_normalizer-3.4.8 idna-3.18 lxml-6.1.1 requests-2.34.2 soupsieve-2.8.4 urllib3-2.7.0

# %%
url = "https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue"

headers = {
    "User-Agent": "MyDataAnalysisBot/1.0 (your_email@example.com)"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# Step 1: Use find_all to get a list of all matching tables
all_tables = soup.find_all('table', class_='wikitable sortable')
# Step 2: Create a list to store your DataFrames
dfs = []
# Step 3: Loop through each table found for table in all_tables:
for table in all_tables:
# Use StringIO to wrap the string version of the table
    df = pd.read_html(StringIO(str(table)))[0]
    dfs.append(df)

df = pd.read_html(StringIO(str(table)))[0]

pd.set_option('display.max_rows', 100)

print(df)
# https://en.wikipedia.org/wiki/List_of_largest_companies_in_Indi/a
# Out:
#    Rank                Name                        Industry  \
# 0     1            Alphabet  Technology and cloud computing
# 1     2               Apple                      Technology
# 2     3  Berkshire Hathaway                    Conglomerate
# 3     4           Microsoft  Technology and cloud computing
# 4     5              Nvidia                      Technology
# 5     6      Meta Platforms                      Technology
# 6     7              Amazon      Retail and cloud computing
# 7     8      JPMorgan Chase                      Financials
# 8     9          ExxonMobil              Petroleum industry
# 9    10     Bank of America                      Financials
#
#    Profits (USD millions)               Headquarters
# 0                  100118  Mountain View, California
# 1                   93736      Cupertino, California
# 2                   88995            Omaha, Nebraska
# 3                   88136        Redmond, Washington
# 4                   72880    Santa Clara, California
# 5                   62360     Menlo Park, California
# 6                   59248        Seattle, Washington
# 7                   58471    New York City, New York
# 8                   33680              Spring, Texas
# 9                   27132  Charlotte, North Carolina

# %%
dfs[0]
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                   UnitedHealth Group
# 3      4                                Apple
# 4      5                           CVS Health
# 5      6                   Berkshire Hathaway
# 6      7                             Alphabet
# 7      8                          Exxon Mobil
# 8      9                 McKesson Corporation
# 9     10                              Cencora
# 10    11                       JPMorgan Chase
# 11    12                     Costco Wholesale
# 12    13                                Cigna
# 13    14                            Microsoft
# 14    15                      Cardinal Health
# 15    16                              Chevron
# 16    17                      Bank of America
# 17    18                       General Motors
# 18    19                           Ford Motor
# 19    20                      Elevance Health
# 20    21                            Citigroup
# 21    22                       Meta Platforms
# 22    23                              Centene
# 23    24                       The Home Depot
# 24    25                           Fannie Mae
# 25    26             Walgreens Boots Alliance
# 26    27                               Kroger
# 27    28                          Phillips 66
# 28    29                   Marathon Petroleum
# 29    30               Verizon Communications
# 30    31                               Nvidia
# 31    32                  Goldman Sachs Group
# 32    33                          Wells Fargo
# 33    34                        Valero Energy
# 34    35                              Comcast
# 35    36                 State Farm Insurance
# 36    37                                 AT&T
# 37    38                          Freddie Mac
# 38    39                               Humana
# 39    40                       Morgan Stanley
# 40    41                               Target
# 41    42                         StoneX Group
# 42    43                                Tesla
# 43    44                    Dell Technologies
# 44    45                              PepsiCo
# 45    46                          Walt Disney
# 46    47                United Parcel Service
# 47    48                    Johnson & Johnson
# 48    49                                FedEx
# 49    50               Archer Daniels Midland
# 50    51                     Procter & Gamble
# 51    52                               Lowe's
# 52    53             Energy Transfer Partners
# 53    54                                  RTX
# 54    55                           Albertsons
# 55    56                                Sysco
# 56    57                          Progressive
# 57    58                     American Express
# 58    59                      Lockheed Martin
# 59    60                              MetLife
# 60    61                       HCA Healthcare
# 61    62                 Prudential Financial
# 62    63                               Boeing
# 63    64                          Caterpillar
# 64    65                                Merck
# 65    66                             Allstate
# 66    67                               Pfizer
# 67    68                                  IBM
# 68    69      New York Life Insurance Company
# 69    70                      Delta Air Lines
# 70    71                 Publix Super Markets
# 71    72  Nationwide Mutual Insurance Company
# 72    73                            TD Synnex
# 73    74             United Airlines Holdings
# 74    75                       ConocoPhillips
# 75    76                                  TJX
# 76    77                               AbbVie
# 77    78         Enterprise Products Partners
# 78    79               Charter Communications
# 79    80               Performance Food Group
# 80    81              American Airlines Group
# 81    82                Capital One Financial
# 82    83                        Cisco Systems
# 83    84                                   HP
# 84    85                          Tyson Foods
# 85    86                                Intel
# 86    87                               Oracle
# 87    88                             Broadcom
# 88    89                                Deere
# 89    90                                 Nike
# 90    91       Liberty Mutual Insurance Group
# 91    92                   Plains GP Holdings
# 92    93                                 USAA
# 93    94                 Bristol-Myers Squibb
# 94    95                 Ingram Micro Holding
# 95    96                     General Dynamics
# 96    97                            Coca-Cola
# 97    98                                 TIAA
# 98    99                            Travelers
# 99   100                            Eli Lilly
#
#                                Industry  Revenue (USD millions)  \
# 0                                Retail                  680985
# 1            Retail and cloud computing                  637959
# 2                            Healthcare                  400278
# 3                            Technology                  391035
# 4                            Healthcare                  372809
# 5                          Conglomerate                  371433
# 6        Technology and cloud computing                  350018
# 7                             Petroleum                  349595
# 8                            Healthcare                  308951
# 9                    Pharmacy wholesale                  293959
# 10                           Financials                  278906
# 11                               Retail                  254453
# 12                     Health insurance                  247121
# 13       Technology and cloud computing                  245122
# 14                           Healthcare                  226827
# 15                            Petroleum                  202792
# 16                           Financials                  192434
# 17                           Automotive                  187442
# 18                           Automotive                  184992
# 19                           Healthcare                  177011
# 20                           Financials                  170757
# 21                           Technology                  164501
# 22                           Healthcare                  163071
# 23                               Retail                  159514
# 24                           Financials                  152670
# 25                       Pharmaceutical                  147658
# 26                               Retail                  147123
# 27                            Petroleum                  145496
# 28                            Petroleum                  140412
# 29                   Telecommunications                  134788
# 30                           Technology                  130497
# 31                           Financials                  126853
# 32                           Financials                  125397
# 33                            Petroleum                  123974
# 34                   Telecommunications                  123731
# 35                           Financials                  122951
# 36  Conglomerate and telecommunications                  122336
# 37                           Financials                  122052
# 38                     Health insurance                  117761
# 39                           Financials                  107285
# 40                               Retail                  106566
# 41                           Financials                   99888
# 42                Automotive and energy                   97690
# 43                           Technology                   95567
# 44                             Beverage                   91854
# 45                                Media                   91361
# 46                       Transportation                   91070
# 47                       Pharmaceutical                   88821
# 48                       Transportation                   87693
# 49                        Food industry                   85530
# 50      Consumer products manufacturing                   84039
# 51                               Retail                   83674
# 52                            Petroleum                   82671
# 53                Aerospace and defense                   80739
# 54                               Retail                   79238
# 55                      Food processing                   78844
# 56                            Insurance                   75372
# 57                           Financials                   74201
# 58                Aerospace and defense                   71043
# 59                           Financials                   70986
# 60                           Healthcare                   70603
# 61                           Financials                   70405
# 62                Aerospace and defense                   66517
# 63                            Machinery                   64809
# 64              Pharmaceutical industry                   64168
# 65                            Insurance                   64106
# 66              Pharmaceutical industry                   63627
# 67       Technology and cloud computing                   62753
# 68                            Insurance                   62639
# 69                              Airline                   61643
# 70                               Retail                   60177
# 71                           Financials                   58646
# 72               Information Technology                   58452
# 73                              Airline                   57063
# 74                            Petroleum                   56953
# 75                               Retail                   56360
# 76                       Pharmaceutical                   56334
# 77                            Petroleum                   56219
# 78                   Telecommunications                   55085
# 79                      Food processing                   54681
# 80                              Airline                   54211
# 81                           Financials                   53938
# 82       Telecom hardware manufacturing                   53803
# 83                           Technology                   53559
# 84                      Food processing                   53309
# 85                           Technology                   53101
# 86                           Technology                   52961
# 87                           Technology                   52432
# 88            Agriculture manufacturing                   51716
# 89                              Apparel                   51361
# 90                            Insurance                   50429
# 91                            Petroleum                   50073
# 92                            Insurance                   48560
# 93                       Pharmaceutical                   48300
# 94                           Technology                   47984
# 95                Aerospace and defense                   47716
# 96                             Beverage                   47061
# 97                           Financials                   46946
# 98                            Insurance                   46423
# 99                       Pharmaceutical                   45043
#
#    Revenue growth  Employees                   Headquarters
# 0            5.1%    2100000          Bentonville, Arkansas
# 1           11.0%    1556000            Seattle, Washington
# 2            7.7%     400000          Minnetonka, Minnesota
# 3            2.0%     164000          Cupertino, California
# 4            4.2%     259500       Woonsocket, Rhode Island
# 5            1.9%     392400                Omaha, Nebraska
# 6           13.9%     183323      Mountain View, California
# 7            1.5%      60900                  Spring, Texas
# 8           11.7%      48000                  Irving, Texas
# 9           12.1%      44000     Conshohocken, Pennsylvania
# 10          16.5%     317233        New York City, New York
# 11           5.0%     333000           Issaquah, Washington
# 12          26.6%      72398        Bloomfield, Connecticut
# 13          15.7%     228000            Redmond, Washington
# 14          10.6%      48411                   Dublin, Ohio
# 15           0.9%      45298                 Houston, Texas
# 16          11.9%     213193      Charlotte, North Carolina
# 17           9.1%     162000              Detroit, Michigan
# 18           5.0%     171000             Dearborn, Michigan
# 19           3.3%     103679          Indianapolis, Indiana
# 20           8.9%     227855        New York City, New York
# 21          21.9%      74067         Menlo Park, California
# 22           5.9%      60500            St. Louis, Missouri
# 23           4.5%     470100               Atlanta, Georgia
# 24           8.1%       8200               Washington, D.C.
# 25           6.2%     252500            Deerfield, Illinois
# 26          -1.9%     409000               Cincinnati, Ohio
# 27          -2.9%      13200                 Houston, Texas
# 28          -6.6%      18300                  Findlay, Ohio
# 29           0.6%      99600        New York City, New York
# 30         114.2%      36000        Santa Clara, California
# 31          17.0%      46500        New York City, New York
# 32           8.7%     217502      San Francisco, California
# 33         -10.8%       9910             San Antonio, Texas
# 34           1.8%     182000     Philadelphia, Pennsylvania
# 35          18.0%      67381          Bloomington, Illinois
# 36          -0.1%     140990                  Dallas, Texas
# 37          13.0%       8090               McLean, Virginia
# 38          10.7%      65680           Louisville, Kentucky
# 39          11.5%      80478        New York City, New York
# 40          -0.8%     440000         Minneapolis, Minnesota
# 41          64.1%       4500        New York City, New York
# 42           0.9%     125665                  Austin, Texas
# 43           8.1%     108000              Round Rock, Texas
# 44           0.4%     319000             Purchase, New York
# 45           2.8%     205040            Burbank, California
# 46           0.1%     372180               Atlanta, Georgia
# 47          -6.7%     138100      New Brunswick, New Jersey
# 48          -2.7%     422100             Memphis, Tennessee
# 49          -8.9%      43213              Chicago, Illinois
# 50           2.5%     108000               Cincinnati, Ohio
# 51          -3.1%     215500    Mooresville, North Carolina
# 52           5.2%      16248                  Dallas, Texas
# 53          17.1%     186000     Arlington County, Virginia
# 54           2.0%     196650                   Boise, Idaho
# 55           3.3%      76000                 Houston, Texas
# 56          21.4%      66308         Mayfield Village, Ohio
# 57          10.1%      75100        New York City, New York
# 58           5.1%     121000             Bethesda, Maryland
# 59           6.1%      45000        New York City, New York
# 60           8.7%     271000           Nashville, Tennessee
# 61          30.4%      37936             Newark, New Jersey
# 62         -14.5%     172000     Arlington County, Virginia
# 63          -3.4%     112900                  Irving, Texas
# 64           6.7%      74000         Kenilworth, New Jersey
# 65          12.3%      55200  Northfield Township, Illinois
# 66           8.8%      81000        New York City, New York
# 67           1.4%     284500               Armonk, New York
# 68          15.3%      15131        New York City, New York
# 69           6.2%     103000               Atlanta, Georgia
# 70           4.6%     255000              Lakeland, Florida
# 71           7.4%      22453                 Columbus, Ohio
# 72           1.6%      25750            Clearwater, Florida
# 73           6.2%     107300              Chicago, Illinois
# 74          -2.8%      11800                 Houston, Texas
# 75           4.0%     364000      Framingham, Massachusetts
# 76           3.7%      55000           Lake Bluff, Illinois
# 77          13.1%       7800                 Houston, Texas
# 78           0.9%      94500          Stamford, Connecticut
# 79           2.5%      36815             Richmond, Virginia
# 80           2.7%     133300              Fort Worth, Texas
# 81           9.0%      52600               Tysons, Virginia
# 82          -5.6%      90400           San Jose, California
# 83          -0.3%      58000          Palo Alto, California
# 84           0.8%     138000           Springdale, Arkansas
# 85          -2.1%     108900        Santa Clara, California
# 86           6.0%     159000                  Austin, Texas
# 87          46.4%      37000          Palo Alto, California
# 88         -15.6%      55524               Moline, Illinois
# 89           0.3%      78400              Beaverton, Oregon
# 90          -4.1%      40000          Boston, Massachusetts
# 91           2.8%       4200                 Houston, Texas
# 92          14.3%      38018             San Antonio, Texas
# 93           7.3%      34100        New York City, New York
# 94          -0.1%      26125             Irvine, California
# 95          12.9%     117000               Reston, Virginia
# 96           2.9%      69700               Atlanta, Georgia
# 97           2.6%      15623        New York City, New York
# 98          12.2%      34000        New York City, New York
# 99          32.0%      47000          Indianapolis, Indiana

# %%
dfs[1]
# Out:
#    Rank                              Name               Industry  \
# 0     1                           Cargill           Food & Drink
# 1     2                              Koch           Multicompany
# 2     3              Publix Super Markets           Food Markets
# 3     4                              Mars           Food & Drink
# 4     5             H-E-B Grocery Company           Food Markets
# 5     6                    Reyes Holdings  Food, Drink & Tobacco
# 6     7               Enterprise Mobility               Services
# 7     8              Fidelity Investments              Insurance
# 8     9  Southern Glazer's Wine & Spirits  Food, Drink & Tobacco
# 9    10                   Cox Enterprises                  Media
#
#    Revenue (USD billions)  Employees           Headquarters
# 0                  154.00     155000  Minnetonka, Minnesota
# 1                  125.00     120000        Wichita, Kansas
# 2                   59.70     260000      Lakeland, Florida
# 3                   55.00     150000       McLean, Virginia
# 4                   49.57     175000     San Antonio, Texas
# 5                   44.00      36000     Rosemont, Illinois
# 6                   38.00     100000      Clayton, Missouri
# 7                   32.70      78000  Boston, Massachusetts
# 8                   25.00      24000       Miramar, Florida
# 9                   23.50      50000       Atlanta, Georgia

# %%
dfs[2]
# Out:
#    Rank                Name                        Industry  \
# 0     1            Alphabet  Technology and cloud computing
# 1     2               Apple                      Technology
# 2     3  Berkshire Hathaway                    Conglomerate
# 3     4           Microsoft  Technology and cloud computing
# 4     5              Nvidia                      Technology
# 5     6      Meta Platforms                      Technology
# 6     7              Amazon      Retail and cloud computing
# 7     8      JPMorgan Chase                      Financials
# 8     9          ExxonMobil              Petroleum industry
# 9    10     Bank of America                      Financials
#
#    Profits (USD millions)               Headquarters
# 0                  100118  Mountain View, California
# 1                   93736      Cupertino, California
# 2                   88995            Omaha, Nebraska
# 3                   88136        Redmond, Washington
# 4                   72880    Santa Clara, California
# 5                   62360     Menlo Park, California
# 6                   59248        Seattle, Washington
# 7                   58471    New York City, New York
# 8                   33680              Spring, Texas
# 9                   27132  Charlotte, North Carolina

# %%
url = "https://en.wikipedia.org/wiki/List_of_largest_companies_in_India"

headers = {
    "User-Agent": "MyDataAnalysisBot/1.0 (your_email@example.com)"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# Step 1: Use find_all to get a list of all matching tables
all_tables = soup.find_all('table', class_='wikitable sortable')
# Step 2: Create a list to store your DataFrames
dfs = []
# Step 3: Loop through each table found for table in all_tables:
for table in all_tables:
# Use StringIO to wrap the string version of the table
    df = pd.read_html(StringIO(str(table)))[0]
    dfs.append(df)

df = pd.read_html(StringIO(str(table)))[0]

pd.set_option('display.max_rows', 100)

print(df)
# Out:
#     Rank                             Name            Industry  \
# 0      1      Reliance Industries Limited        Conglomerate
# 1      2       Life Insurance Corporation           Insurance
# 2      3           Indian Oil Corporation         Oil and gas
# 3      4              State Bank of India             Banking
# 4      5  Oil and Natural Gas Corporation         Oil and gas
# 5      6                        HDFC Bank             Banking
# 6      7                      Tata Motors          Automotive
# 7      8                 Bharat Petroleum         Oil and gas
# 8      9                       ICICI Bank             Banking
# 9     10                  Larsen & Toubro       Capital goods
# 10    11        Tata Consultancy Services            Infotech
# 11    12              Hindalco Industries   Metals and mining
# 12    13                       Tata Steel      Iron and steel
# 13    14                     NTPC Limited           Utilities
# 14    15                    Bharti Airtel  Telecommunications
# 15    16                    JSW Steel Ltd      Iron and steel
# 16    17                          Infosys            Infotech
# 17    18              Mahindra & Mahindra          Automotive
# 18    19                Vedanta Resources   Metals and mining
# 19    20              Maruti Suzuki India          Automotive
# 20    21                        Axis Bank             Banking
# 21    22                       Coal India   Metals and mining
# 22    23                   Bank of Baroda             Banking
# 23    24                      Canara Bank             Banking
# 24    25                Grasim Industries         Diversified
# 25    26                             GAIL         Oil and gas
# 26    27             Punjab National Bank             Banking
# 27    28                    Bajaj Finserv          Financials
# 28    29                    Nayara Energy         Oil and gas
# 29    30              Union Bank of India             Banking
# 30    31                 HCL Technologies            Infotech
# 31    32           Motherson Sumi Systems          Automotive
# 32    33        Power Finance Corporation  Financial services
# 33    34              Kotak Mahindra Bank             Banking
# 34    35         Steel Authority of India      Iron and steel
# 35    36                      ITC Limited      Consumer goods
# 36    37                            Wipro            Infotech
# 37    38                         Flipkart          E-commerce
# 38    39                           IndiGo             Airline
# 39    40                    Bank of India             Banking
# 40    41                      Indian Bank             Banking
# 41    42              Hyundai Motor India          Automotive
# 42    43                       Tata Power           Utilities
# 43    44                    Titan Company  Gems and jewellery
# 44    45           Toyota Kirloskar Motor          Automotive
# 45    46               Hindustan Unilever      Consumer goods
# 46    47                Adani Enterprises             Trading
# 47    48                AWL Agri Business      Consumer goods
# 48    49                Avenue Supermarts              Retail
# 49    50                           NABARD             Finance
#
#     Revenue (in ₹ crore) Revenue growth Profits (in ₹ crore) Headquarters  \
# 0                 997795             8%                69648       Mumbai
# 1                 893465             4%                48320       Mumbai
# 2                 766008             2%                13598    New Delhi
# 3                 663343            12%                77561       Mumbai
# 4                 624805             0%                36226    New Delhi
# 5                 470916            15%                70792       Mumbai
# 6                 449357             2%                27830       Mumbai
# 7                 443948             2%                13337       Mumbai
# 8                 294587            25%                51029       Mumbai
# 9                 260745            16%                15037       Mumbai
# 10                259286             6%                48553       Mumbai
# 11                243534            13%                16001       Mumbai
# 12                220507             3%                 3421       Mumbai
# 13                196847             7%                23422    New Delhi
# 14                194387            26%                33556    New Delhi
# 15                168689             6%                26713       Mumbai
# 16                166590             6%                28165    Bangalore
# 17                162941            13%                12929       Mumbai
# 18                160450             7%                14988   London, UK
# 19                159407             8%                14500    New Delhi
# 20                155917            13%                28055       Mumbai
# 21                155605             1%                35358      Kolkata
# 22                152884             8%                20716     Vadodara
# 23                152658            10%                17540    Bangalore
# 24                151048            14%                 3706       Mumbai
# 25                147417             8%                12450    New Delhi
# 26                141570            15%                18480    New Delhi
# 27                133840            21%                 8872         Pune
# 28                130326             3%                 6080       Mumbai
# 29                129979            10%                18027       Mumbai
# 30                119488             7%                17390        Noida
# 31                114502            16%                 3803        Noida
# 32                107203            17%                22991    New Delhi
# 33                107095            14%                22126       Mumbai
# 34                103861             6%                 2372    New Delhi
# 35                 93705            31%                34747      Kolkata
# 36                 92937             1%                13135    Bangalore
# 37                 84230            18%               −5,189    Bangalore
# 38                 84098            18%                 7258      Gurgaon
# 39                 80625            19%                 9548       Mumbai
# 40                 72051            12%                11261      Chennai
# 41                 70282             2%                 5640      Gurgaon
# 42                 68892             6%                 3971       Mumbai
# 43                 68758            27%                 3337    Bangalore
# 44                 65958            16%                 5672       Bidadi
# 45                 64891             3%                10649       Mumbai
# 46                 62652            12%                 7112    Ahmedabad
# 47                 61387            24%                 1226    Ahmedabad
# 48                 60599            17%                 2708       Mumbai
# 49                 59292            20%                 7803       Mumbai
#
#    State controlled
# 0               NaN
# 1               Yes
# 2               Yes
# 3               Yes
# 4               Yes
# 5               NaN
# 6               NaN
# 7               Yes
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              Yes
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              Yes
# 21              Yes
# 22              Yes
# 23              Yes
# 24              NaN
# 25              Yes
# 26              Yes
# 27              NaN
# 28              NaN
# 29              Yes
# 30              NaN
# 31              NaN
# 32              Yes
# 33              NaN
# 34              Yes
# 35              NaN
# 36              NaN
# 37              NaN
# 38              NaN
# 39              Yes
# 40              Yes
# 41              NaN
# 42              NaN
# 43              NaN
# 44              NaN
# 45              NaN
# 46              NaN
# 47              NaN
# 48              NaN
# 49              Yes

# %%
dfs[0]
# Out:
#     Rank  Forbes  2000 rank                                Name Headquarters  \
# 0      1                 49         Reliance Industries Limited       Mumbai
# 1      2                 55                 State Bank of India       Mumbai
# 2      3                 65                           HDFC Bank       Mumbai
# 3      4                 70          Life Insurance Corporation    New Delhi
# 4      5                142                          ICICI Bank       Mumbai
# 5      6                207     Oil and Natural Gas Corporation    New Delhi
# 6      7                259              Indian Oil Corporation    New Delhi
# 7      8                284                         Tata Motors       Mumbai
# 8      9                293                           Axis Bank       Mumbai
# 9     10                372                        NTPC Limited    New Delhi
# 10    11                398                     Larsen & Toubro       Mumbai
# 11    12                412           Tata Consultancy Services       Mumbai
# 12    13                440                      Bank of Baroda     Vadodara
# 13    14                442                 Kotak Mahindra Bank       Mumbai
# 14    15                472                       Bharti Airtel    New Delhi
# 15    16                488                          Coal India      Kolkata
# 16    17                525                         Canara Bank    Bangalore
# 17    18                533           Power Finance Corporation    New Delhi
# 18    19                537                    Bharat Petroleum       Mumbai
# 19    20                569                             Infosys    Bangalore
# 20    21                571                Punjab National Bank    New Delhi
# 21    22                575                 Union Bank of India       Mumbai
# 22    23                592                       Bajaj Finserv         Pune
# 23    24                593                 Mahindra & Mahindra       Mumbai
# 24    25                645                       JSW Steel Ltd       Mumbai
# 25    26                684                 Hindalco Industries       Mumbai
# 26    27                746                   Grasim Industries       Mumbai
# 27    28                764                    HCL Technologies        Noida
# 28    29                810                         ITC Limited      Kolkata
# 29    30                827     Power Grid Corporation of India      Gurgaon
# 30    31                834                          Tata Steel      Kolkata
# 31    32                901                       IndusInd Bank       Mumbai
# 32    33                922  Indian Railway Finance Corporation    New Delhi
# 33    34                926                               Wipro    Bangalore
# 34    35                930                                GAIL    New Delhi
# 35    36                947                         Indian Bank      Chennai
# 36    37                961                     Vedanta Limited       Mumbai
# 37    38               1048                         Adani Power    Ahmedabad
# 38    39               1053                       Bank of India       Mumbai
# 39    40               1059                   Adani Enterprises    Ahmedabad
# 40    41               1161                  Sun Pharmaceutical       Mumbai
# 41    42               1212                              IndiGo      Gurgaon
# 42    43               1219                   Adani Ports & SEZ    Ahmedabad
# 43    44               1259                           IDBI Bank       Mumbai
# 44    45               1264                          Bajaj Auto         Pune
# 45    46               1281           Shriram Transport Finance      Chennai
# 46    47               1384                        Asian Paints       Mumbai
# 47    48               1534                          Tata Power       Mumbai
# 48    49               1562                       Titan Company    Bangalore
# 49    50               1604              Jio Financial Services       Mumbai
# 50    49               1568                      Rajesh Exports    Bangalore
# 51    50               1617                               DMart       Mumbai
# 52    51               1693              Jindal Steel and Power    New Delhi
# 53    52               1697                 LIC Housing Finance       Mumbai
# 54    53               1699                  Adani Green Energy    Ahmedabad
# 55    54               1704         Bajaj Holdings & Investment       Mumbai
# 56    55               1760       General Insurance Corporation       Mumbai
# 57    56               1769                            Yes Bank       Mumbai
# 58    57               1805              Motherson Sumi Systems        Noida
# 59    58               1821                  Bharat Electronics    Bangalore
# 60    59               1840               Central Bank of India       Mumbai
# 61    60               1842                 Bank of Maharashtra         Pune
# 62    61               1848                        Indus Towers      Gurgaon
# 63    62               1853            Steel Authority of India    New Delhi
# 64    63               1869                        Federal Bank        Kochi
# 65    64               1873                                 DLF      Gurgaon
# 66    65               1895            Dr. Reddy's Laboratories    Hyderabad
# 67    66               1908                     Varun Beverages      Gurgaon
# 68    67               1949                               CIFCL      Chennai
# 69    68               1957                                NMDC    Hyderabad
# 70    69               1980                           ABB India    Bangalore
#
#     Revenue (billions US$) Profit (billions US$)  Assets (billions US$)  \
# 0                    108.8                   8.4                  210.5
# 1                     71.8                   8.1                  807.4
# 2                     49.3                   7.7                  483.2
# 3                     98.0                   4.9                  561.4
# 4                     28.5                   5.3                  283.5
# 5                     77.5                   5.1                   80.6
# 6                     93.8                   5.0                   57.8
# 7                     52.9                   3.8                   44.4
# 8                     16.7                   3.2                  182.0
# 9                     21.2                   2.4                   54.7
# 10                    26.7                   1.6                   40.7
# 11                    29.1                   5.5                   17.6
# 12                    17.1                   2.3                  198.4
# 13                    11.4                   2.2                   92.0
# 14                    18.1                   0.9                   53.3
# 15                    17.2                   3.9                   28.5
# 16                    16.8                   1.8                  184.0
# 17                    11.1                   2.4                  124.6
# 18                    54.1                   3.2                   24.3
# 19                    18.6                   3.2                   16.5
# 20                    14.8                   1.1                  191.7
# 21                    14.3                   1.7                  168.1
# 22                    13.0                   1.0                   64.5
# 23                    16.8                   1.4                   28.3
# 24                    21.1                   1.1                   27.4
# 25                    26.1                   1.1                   27.1
# 26                    15.3                   0.7                   47.0
# 27                    13.3                   1.9                   12.0
# 28                     8.5                   2.5                   10.5
# 29                     5.6                   1.9                   29.6
# 30                    28.3                  −0.4                   32.7
# 31                     6.7                   1.1                   61.8
# 32                     3.2                   0.7                   58.6
# 33                    10.8                   1.3                   13.8
# 34                    16.1                   1.2                   15.0
# 35                     7.8                   1.0                   95.4
# 36                    17.4                   0.5                   22.9
# 37                     6.1                   2.5                   11.1
# 38                     8.1                   0.8                  110.8
# 39                    12.7                   0.4                   19.3
# 40                     5.7                   1.1                    9.6
# 41                     7.9                   0.9                    8.8
# 42                     3.2                   1.0                   14.3
# 43                     3.7                   0.7                   43.7
# 44                     5.4                   0.9                    4.7
# 45                     4.4                   0.9                   29.8
# 46                     4.3                   0.7                    3.6
# 47                     7.4                   0.5                   16.7
# 48                     6.2                   0.0                    2.3
# 49                     0.2                   0.2                   17.4
# 50                    32.6                   0.1                    4.1
# 51                     6.1                   0.3                    2.5
# 52                     6.0                   0.6                    9.4
# 53                     3.3                   0.4                   34.9
# 54                     1.1                   0.1                   10.6
# 55                     0.2                   0.9                    7.8
# 56                     5.7                   0.9                   20.9
# 57                     4.0                   0.2                   48.7
# 58                    11.4                   0.2                    9.4
# 59                     2.2                   0.4                    4.4
# 60                     4.3                   0.3                   53.7
# 61                     2.8                   0.5                   36.8
# 62                     3.5                   0.7                    6.7
# 63                    12.9                   0.4                   15.6
# 64                     3.2                   0.5                   38.1
# 65                     0.8                   0.3                    7.2
# 66                     3.4                   0.7                    4.6
# 67                     2.0                   0.3                    1.8
# 68                     2.3                   0.4                   18.8
# 69                     2.5                   0.8                    3.9
# 70                     1.3                   0.2                    1.3
#
#     Value (billions US$)               Industry
# 0                  233.1           Conglomerate
# 1                   87.6                Banking
# 2                  133.6                Banking
# 3                   73.6              Insurance
# 4                   95.3                Banking
# 5                   41.9            Oil and gas
# 6                   27.8            Oil and gas
# 7                   43.8             Automotive
# 8                   42.3                Banking
# 9                   42.5              Utilities
# 10                  56.9          Capital goods
# 11                 166.5               Infotech
# 12                  16.2                Banking
# 13                  40.5                Banking
# 14                  91.5      Telecommunication
# 15                  34.8      Metals and mining
# 16                  12.4                Banking
# 17                  18.5             Financials
# 18                  16.4            Oil and gas
# 19                  71.9               Infotech
# 20                  16.5                Banking
# 21                  12.7                Banking
# 22                  30.3             Financials
# 23                  37.5             Automotive
# 24                  26.6         Iron and steel
# 25                  17.7      Metals and mining
# 26                  19.8            Diversified
# 27                  43.4               Infotech
# 28                  65.4         Consumer goods
# 29                  35.0              Utilities
# 30                  25.1         Iron and steel
# 31                  13.2                Banking
# 32                  26.5             Financials
# 33                  28.9               Infotech
# 34                  16.1            Oil and gas
# 35                   8.7                Banking
# 36                  19.7      Metals and mining
# 37                  29.4                 Energy
# 38                   6.7                Banking
# 39                  41.9                Holding
# 40                  44.1        Pharmaceuticals
# 41                  20.2                Airline
# 42                  34.6               Shipping
# 43                  10.9                Banking
# 44                  29.4             Automotive
# 45                  10.7             Financials
# 46                  32.3              Chemicals
# 47                  16.7              Utilities
# 48                   1.1     Gems and jewellery
# 49                  27.2             Financials
# 50                   2.0     Gems and jewellery
# 51                  36.6                 Retail
# 52                  12.4         Iron and steel
# 53                   4.3             Financials
# 54                  34.8       Renewable energy
# 55                  11.0                Holding
# 56                   7.2              Insurance
# 57                   8.3                Banking
# 58                  10.5             Automotive
# 59                  21.8  Aerospace and defense
# 60                   6.4                Banking
# 61                   5.5                Banking
# 62                  11.1      Telecommunication
# 63                   8.3         Iron and steel
# 64                   4.8                Banking
# 65                  25.2            Real estate
# 66                  11.6        Pharmaceuticals
# 67                  23.6              Beverages
# 68                  13.0             Financials
# 69                   9.7                 Mining
# 70                  21.3          Capital goods

# %%
dfs[1]
# Out:
#     Rank                             Name            Industry  \
# 0      1      Reliance Industries Limited        Conglomerate
# 1      2       Life Insurance Corporation           Insurance
# 2      3           Indian Oil Corporation         Oil and gas
# 3      4              State Bank of India             Banking
# 4      5  Oil and Natural Gas Corporation         Oil and gas
# 5      6                        HDFC Bank             Banking
# 6      7                      Tata Motors          Automotive
# 7      8                 Bharat Petroleum         Oil and gas
# 8      9                       ICICI Bank             Banking
# 9     10                  Larsen & Toubro       Capital goods
# 10    11        Tata Consultancy Services            Infotech
# 11    12              Hindalco Industries   Metals and mining
# 12    13                       Tata Steel      Iron and steel
# 13    14                     NTPC Limited           Utilities
# 14    15                    Bharti Airtel  Telecommunications
# 15    16                    JSW Steel Ltd      Iron and steel
# 16    17                          Infosys            Infotech
# 17    18              Mahindra & Mahindra          Automotive
# 18    19                Vedanta Resources   Metals and mining
# 19    20              Maruti Suzuki India          Automotive
# 20    21                        Axis Bank             Banking
# 21    22                       Coal India   Metals and mining
# 22    23                   Bank of Baroda             Banking
# 23    24                      Canara Bank             Banking
# 24    25                Grasim Industries         Diversified
# 25    26                             GAIL         Oil and gas
# 26    27             Punjab National Bank             Banking
# 27    28                    Bajaj Finserv          Financials
# 28    29                    Nayara Energy         Oil and gas
# 29    30              Union Bank of India             Banking
# 30    31                 HCL Technologies            Infotech
# 31    32           Motherson Sumi Systems          Automotive
# 32    33        Power Finance Corporation  Financial services
# 33    34              Kotak Mahindra Bank             Banking
# 34    35         Steel Authority of India      Iron and steel
# 35    36                      ITC Limited      Consumer goods
# 36    37                            Wipro            Infotech
# 37    38                         Flipkart          E-commerce
# 38    39                           IndiGo             Airline
# 39    40                    Bank of India             Banking
# 40    41                      Indian Bank             Banking
# 41    42              Hyundai Motor India          Automotive
# 42    43                       Tata Power           Utilities
# 43    44                    Titan Company  Gems and jewellery
# 44    45           Toyota Kirloskar Motor          Automotive
# 45    46               Hindustan Unilever      Consumer goods
# 46    47                Adani Enterprises             Trading
# 47    48                AWL Agri Business      Consumer goods
# 48    49                Avenue Supermarts              Retail
# 49    50                           NABARD             Finance
#
#     Revenue (in ₹ crore) Revenue growth Profits (in ₹ crore) Headquarters  \
# 0                 997795             8%                69648       Mumbai
# 1                 893465             4%                48320       Mumbai
# 2                 766008             2%                13598    New Delhi
# 3                 663343            12%                77561       Mumbai
# 4                 624805             0%                36226    New Delhi
# 5                 470916            15%                70792       Mumbai
# 6                 449357             2%                27830       Mumbai
# 7                 443948             2%                13337       Mumbai
# 8                 294587            25%                51029       Mumbai
# 9                 260745            16%                15037       Mumbai
# 10                259286             6%                48553       Mumbai
# 11                243534            13%                16001       Mumbai
# 12                220507             3%                 3421       Mumbai
# 13                196847             7%                23422    New Delhi
# 14                194387            26%                33556    New Delhi
# 15                168689             6%                26713       Mumbai
# 16                166590             6%                28165    Bangalore
# 17                162941            13%                12929       Mumbai
# 18                160450             7%                14988   London, UK
# 19                159407             8%                14500    New Delhi
# 20                155917            13%                28055       Mumbai
# 21                155605             1%                35358      Kolkata
# 22                152884             8%                20716     Vadodara
# 23                152658            10%                17540    Bangalore
# 24                151048            14%                 3706       Mumbai
# 25                147417             8%                12450    New Delhi
# 26                141570            15%                18480    New Delhi
# 27                133840            21%                 8872         Pune
# 28                130326             3%                 6080       Mumbai
# 29                129979            10%                18027       Mumbai
# 30                119488             7%                17390        Noida
# 31                114502            16%                 3803        Noida
# 32                107203            17%                22991    New Delhi
# 33                107095            14%                22126       Mumbai
# 34                103861             6%                 2372    New Delhi
# 35                 93705            31%                34747      Kolkata
# 36                 92937             1%                13135    Bangalore
# 37                 84230            18%               −5,189    Bangalore
# 38                 84098            18%                 7258      Gurgaon
# 39                 80625            19%                 9548       Mumbai
# 40                 72051            12%                11261      Chennai
# 41                 70282             2%                 5640      Gurgaon
# 42                 68892             6%                 3971       Mumbai
# 43                 68758            27%                 3337    Bangalore
# 44                 65958            16%                 5672       Bidadi
# 45                 64891             3%                10649       Mumbai
# 46                 62652            12%                 7112    Ahmedabad
# 47                 61387            24%                 1226    Ahmedabad
# 48                 60599            17%                 2708       Mumbai
# 49                 59292            20%                 7803       Mumbai
#
#    State controlled
# 0               NaN
# 1               Yes
# 2               Yes
# 3               Yes
# 4               Yes
# 5               NaN
# 6               NaN
# 7               Yes
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              Yes
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              Yes
# 21              Yes
# 22              Yes
# 23              Yes
# 24              NaN
# 25              Yes
# 26              Yes
# 27              NaN
# 28              NaN
# 29              Yes
# 30              NaN
# 31              NaN
# 32              Yes
# 33              NaN
# 34              Yes
# 35              NaN
# 36              NaN
# 37              NaN
# 38              NaN
# 39              Yes
# 40              Yes
# 41              NaN
# 42              NaN
# 43              NaN
# 44              NaN
# 45              NaN
# 46              NaN
# 47              NaN
# 48              NaN
# 49              Yes

# %%
url = "https://en.wikipedia.org/wiki/List_of_Indian_IT_companies"

headers = {
    "User-Agent": "MyDataAnalysisBot/1.0 (your_email@example.com)"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# Step 1: Use find_all to get a list of all matching tables
all_tables = soup.find_all('table', class_='wikitable sortable')
# Step 2: Create a list to store your DataFrames
dfs = []
# Step 3: Loop through each table found for table in all_tables:
for table in all_tables:
# Use StringIO to wrap the string version of the table
    df = pd.read_html(StringIO(str(table)))[0]
    dfs.append(df)

df = pd.read_html(StringIO(str(table)))[0]

pd.set_option('display.max_rows', 100)
print(df)
# Out:
#                                   Name                           Headquarters  \
# 0                          3i Infotech                                 Mumbai
# 1                          3i Infotech                                 Mumbai
# 2                          3i Infotech                                 Mumbai
# 3                          3i Infotech                                 Mumbai
# 4            NTT Data Payment Services                                 Mumbai
# 5                                C-DAC                                   Pune
# 6                                C-DAC                                   Pune
# 7                                C-DAC                                   Pune
# 8                              Coforge            Noida India, New Jersey USA
# 9                              Coforge            Noida India, New Jersey USA
# 10                             Coforge            Noida India, New Jersey USA
# 11                             Coforge            Noida India, New Jersey USA
# 12                             Coforge            Noida India, New Jersey USA
# 13                             Coforge            Noida India, New Jersey USA
# 14                             Coforge            Noida India, New Jersey USA
# 15                             Coforge            Noida India, New Jersey USA
# 16                             Coforge            Noida India, New Jersey USA
# 17                             Coforge            Noida India, New Jersey USA
# 18                             Coforge            Noida India, New Jersey USA
# 19                           Cognizant                    Teaneck, New Jersey
# 20                           Cognizant                    Teaneck, New Jersey
# 21                           Cognizant                    Teaneck, New Jersey
# 22                           Cognizant                    Teaneck, New Jersey
# 23                           Cognizant                    Teaneck, New Jersey
# 24                           Cognizant                    Teaneck, New Jersey
# 25                           Cognizant                    Teaneck, New Jersey
# 26                           Cognizant                    Teaneck, New Jersey
# 27                           Cognizant                    Teaneck, New Jersey
# 28                           Cognizant                    Teaneck, New Jersey
# 29                           Collabera  Morristown, New Jersey, United States
# 30                           Collabera  Morristown, New Jersey, United States
# 31                           Collabera  Morristown, New Jersey, United States
# 32                           Collabera  Morristown, New Jersey, United States
# 33                           Collabera  Morristown, New Jersey, United States
# 34                           Collabera  Morristown, New Jersey, United States
# 35                      DXC Technology                      Ashburn, Virginia
# 36                              Cyient                              Hyderabad
# 37                              Cyient                              Hyderabad
# 38                         Firstsource                                 Mumbai
# 39                         Firstsource                                 Mumbai
# 40                     Godrej Infotech                                 Mumbai
# 41                           Honeywell              Morris Plains, New Jersey
# 42               HSBC Technology India                                   Pune
# 43                   KPIT Technologies                                   Pune
# 44                   KPIT Technologies                                   Pune
# 45                   KPIT Technologies                                   Pune
# 46                   KPIT Technologies                                   Pune
# 47                   KPIT Technologies                                   Pune
# 48                   KPIT Technologies                                   Pune
# 49                  Lumen Technologies                          Bengaluru[11]
# 50                  Lumen Technologies                          Bengaluru[11]
# 51                  Lumen Technologies                          Bengaluru[11]
# 52                  Lumen Technologies                          Bengaluru[11]
# 53                           Microland                              Bangalore
# 54                           Microsoft                              Hyderabad
# 55                           Microsoft                              Hyderabad
# 56                           Microsoft                              Hyderabad
# 57                           Microsoft                              Hyderabad
# 58                           Microsoft                              Hyderabad
# 59                           Microsoft                              Hyderabad
# 60                           Microsoft                              Hyderabad
# 61                           Microsoft                              Hyderabad
# 62                           Microsoft                              Hyderabad
# 63            Nucleus Software Exports                                  Noida
# 64                  Persistent Systems                                   Pune
# 65                  Persistent Systems                                   Pune
# 66                  Persistent Systems                                   Pune
# 67                  Persistent Systems                                   Pune
# 68                  Persistent Systems                                   Pune
# 69                       Ramco Systems                                Chennai
# 70                       Ramco Systems                                Chennai
# 71                          Rediff.com                                 Mumbai
# 72       Samsung India Software Centre                                  Noida
# 73                 Sasken Technologies                              Bangalore
# 74                 Sasken Technologies                              Bangalore
# 75                 Sasken Technologies                              Bangalore
# 76                     Sonata Software                              Bangalore
# 77                     Sonata Software                              Bangalore
# 78                          EVRY India                              Bangalore
# 79            Tata Interactive Systems                                 Mumbai
# 80            Tata Interactive Systems                                Chennai
# 81            Tata Interactive Systems                                  Kochi
# 82            Tata Interactive Systems                     Thiruvananthapuram
# 83            Tata Interactive Systems                              Hyderabad
# 84            Tata Interactive Systems                                   Pune
# 85                 WNS Global Services                                 Mumbai
# 86                 WNS Global Services                                 Mumbai
# 87                 Zensar Technologies                                   Pune
# 88                 Zensar Technologies                                   Pune
# 89                 Zensar Technologies                                   Pune
# 90                 Zensar Technologies                                   Pune
# 91                     Tally Solutions                              Bangalore
# 92                    Zoho Corporation                                Chennai
# 93  Kellton Tech Solutions Limited[13]                              Hyderabad
# 94  Kellton Tech Solutions Limited[13]                              Hyderabad
#
#                   City
# 0            Bengaluru
# 1            Hyderabad
# 2               Mumbai
# 3                Noida
# 4               Mumbai
# 5              Kolkata
# 6                 Pune
# 7   Thiruvananthapuram
# 8            New Delhi
# 9        Greater Noida
# 10             Kolkata
# 11             Gurgaon
# 12              Mumbai
# 13           Hyderabad
# 14           Telangana
# 15           Karnataka
# 16           Bengaluru
# 17                Pune
# 18            Kolhapur
# 19           Bengaluru
# 20             Chennai
# 21       Coimbatore[9]
# 22             Gurgaon
# 23           Hyderabad
# 24               Kochi
# 25             Kolkata
# 26       Mangalore[10]
# 27              Mumbai
# 28                Pune
# 29           Bengaluru
# 30             Gurgaon
# 31           Hyderabad
# 32              Mumbai
# 33             Kolkata
# 34                Pune
# 35             Chennai
# 36           Bengaluru
# 37           Hyderabad
# 38         Bhubaneswar
# 39             Kolkata
# 40              Mumbai
# 41             Madurai
# 42                Pune
# 43                Pune
# 44             Chennai
# 45           Bengaluru
# 46               Kochi
# 47              Mumbai
# 48               Noida
# 49           Bengaluru
# 50             Chennai
# 51           Hyderabad
# 52               Noida
# 53           Bengaluru
# 54           Ahmedabad
# 55           Bangalore
# 56             Chennai
# 57             Gurgaon
# 58           Hyderabad
# 59               Kochi
# 60             Kolkata
# 61              Mumbai
# 62           New Delhi
# 63               Noida
# 64           Bengaluru
# 65                 Goa
# 66           Hyderabad
# 67              Nagpur
# 68                Pune
# 69             Chennai
# 70              Mumbai
# 71              Mumbai
# 72               Noida
# 73           Bengaluru
# 74             Chennai
# 75                Pune
# 76           Bengaluru
# 77          Mumbai[12]
# 78           Bangalore
# 79              Mumbai
# 80                 NaN
# 81                 NaN
# 82                 NaN
# 83                 NaN
# 84                 NaN
# 85              Mumbai
# 86              Nashik
# 87           Hyderabad
# 88           Bengaluru
# 89              Mumbai
# 90                Pune
# 91           Bangalore
# 92             Chennai
# 93             Gurgaon
# 94             Lucknow

# %%
dfs[0]
# Out:
#                           Name Headquarters                    Total income  \
# 0    Tata Consultancy Services       Mumbai  ₹ 2,59,282 cr US$31 B  (FY'25)
# 1    Tata Consultancy Services       Mumbai  ₹ 2,59,282 cr US$31 B  (FY'25)
# 2    Tata Consultancy Services       Mumbai  ₹ 2,59,282 cr US$31 B  (FY'25)
# 3    Tata Consultancy Services       Mumbai  ₹ 2,59,282 cr US$31 B  (FY'25)
# 4    Tata Consultancy Services       Mumbai  ₹ 2,59,282 cr US$31 B  (FY'25)
# ..                         ...          ...                             ...
# 100                    Mphasis    Bangalore   ₹ 14,484 cr US$1.7 B  (FY'25)
# 101                    Mphasis    Bangalore   ₹ 14,484 cr US$1.7 B  (FY'25)
# 102                    Mphasis    Bangalore   ₹ 14,484 cr US$1.7 B  (FY'25)
# 103                    Mphasis    Bangalore   ₹ 14,484 cr US$1.7 B  (FY'25)
# 104                        NaN          NaN                             NaN
#
#            Headcount         City
# 0    607,979 (FY'25)    Ahmedabad
# 1    607,979 (FY'25)    Bengaluru
# 2    607,979 (FY'25)  Bhubaneswar
# 3    607,979 (FY'25)      Chennai
# 4    607,979 (FY'25)   Coimbatore
# ..               ...          ...
# 100   33,771 (FY'23)      Chennai
# 101   33,771 (FY'23)    Mangalore
# 102   33,771 (FY'23)       Mumbai
# 103   33,771 (FY'23)         Pune
# 104              NaN          NaN
#
# [105 rows x 5 columns]

# %%
dfs[1]
# Out:
#                                   Name                           Headquarters  \
# 0                          3i Infotech                                 Mumbai
# 1                          3i Infotech                                 Mumbai
# 2                          3i Infotech                                 Mumbai
# 3                          3i Infotech                                 Mumbai
# 4            NTT Data Payment Services                                 Mumbai
# 5                                C-DAC                                   Pune
# 6                                C-DAC                                   Pune
# 7                                C-DAC                                   Pune
# 8                              Coforge            Noida India, New Jersey USA
# 9                              Coforge            Noida India, New Jersey USA
# 10                             Coforge            Noida India, New Jersey USA
# 11                             Coforge            Noida India, New Jersey USA
# 12                             Coforge            Noida India, New Jersey USA
# 13                             Coforge            Noida India, New Jersey USA
# 14                             Coforge            Noida India, New Jersey USA
# 15                             Coforge            Noida India, New Jersey USA
# 16                             Coforge            Noida India, New Jersey USA
# 17                             Coforge            Noida India, New Jersey USA
# 18                             Coforge            Noida India, New Jersey USA
# 19                           Cognizant                    Teaneck, New Jersey
# 20                           Cognizant                    Teaneck, New Jersey
# 21                           Cognizant                    Teaneck, New Jersey
# 22                           Cognizant                    Teaneck, New Jersey
# 23                           Cognizant                    Teaneck, New Jersey
# 24                           Cognizant                    Teaneck, New Jersey
# 25                           Cognizant                    Teaneck, New Jersey
# 26                           Cognizant                    Teaneck, New Jersey
# 27                           Cognizant                    Teaneck, New Jersey
# 28                           Cognizant                    Teaneck, New Jersey
# 29                           Collabera  Morristown, New Jersey, United States
# 30                           Collabera  Morristown, New Jersey, United States
# 31                           Collabera  Morristown, New Jersey, United States
# 32                           Collabera  Morristown, New Jersey, United States
# 33                           Collabera  Morristown, New Jersey, United States
# 34                           Collabera  Morristown, New Jersey, United States
# 35                      DXC Technology                      Ashburn, Virginia
# 36                              Cyient                              Hyderabad
# 37                              Cyient                              Hyderabad
# 38                         Firstsource                                 Mumbai
# 39                         Firstsource                                 Mumbai
# 40                     Godrej Infotech                                 Mumbai
# 41                           Honeywell              Morris Plains, New Jersey
# 42               HSBC Technology India                                   Pune
# 43                   KPIT Technologies                                   Pune
# 44                   KPIT Technologies                                   Pune
# 45                   KPIT Technologies                                   Pune
# 46                   KPIT Technologies                                   Pune
# 47                   KPIT Technologies                                   Pune
# 48                   KPIT Technologies                                   Pune
# 49                  Lumen Technologies                          Bengaluru[11]
# 50                  Lumen Technologies                          Bengaluru[11]
# 51                  Lumen Technologies                          Bengaluru[11]
# 52                  Lumen Technologies                          Bengaluru[11]
# 53                           Microland                              Bangalore
# 54                           Microsoft                              Hyderabad
# 55                           Microsoft                              Hyderabad
# 56                           Microsoft                              Hyderabad
# 57                           Microsoft                              Hyderabad
# 58                           Microsoft                              Hyderabad
# 59                           Microsoft                              Hyderabad
# 60                           Microsoft                              Hyderabad
# 61                           Microsoft                              Hyderabad
# 62                           Microsoft                              Hyderabad
# 63            Nucleus Software Exports                                  Noida
# 64                  Persistent Systems                                   Pune
# 65                  Persistent Systems                                   Pune
# 66                  Persistent Systems                                   Pune
# 67                  Persistent Systems                                   Pune
# 68                  Persistent Systems                                   Pune
# 69                       Ramco Systems                                Chennai
# 70                       Ramco Systems                                Chennai
# 71                          Rediff.com                                 Mumbai
# 72       Samsung India Software Centre                                  Noida
# 73                 Sasken Technologies                              Bangalore
# 74                 Sasken Technologies                              Bangalore
# 75                 Sasken Technologies                              Bangalore
# 76                     Sonata Software                              Bangalore
# 77                     Sonata Software                              Bangalore
# 78                          EVRY India                              Bangalore
# 79            Tata Interactive Systems                                 Mumbai
# 80            Tata Interactive Systems                                Chennai
# 81            Tata Interactive Systems                                  Kochi
# 82            Tata Interactive Systems                     Thiruvananthapuram
# 83            Tata Interactive Systems                              Hyderabad
# 84            Tata Interactive Systems                                   Pune
# 85                 WNS Global Services                                 Mumbai
# 86                 WNS Global Services                                 Mumbai
# 87                 Zensar Technologies                                   Pune
# 88                 Zensar Technologies                                   Pune
# 89                 Zensar Technologies                                   Pune
# 90                 Zensar Technologies                                   Pune
# 91                     Tally Solutions                              Bangalore
# 92                    Zoho Corporation                                Chennai
# 93  Kellton Tech Solutions Limited[13]                              Hyderabad
# 94  Kellton Tech Solutions Limited[13]                              Hyderabad
#
#                   City
# 0            Bengaluru
# 1            Hyderabad
# 2               Mumbai
# 3                Noida
# 4               Mumbai
# 5              Kolkata
# 6                 Pune
# 7   Thiruvananthapuram
# 8            New Delhi
# 9        Greater Noida
# 10             Kolkata
# 11             Gurgaon
# 12              Mumbai
# 13           Hyderabad
# 14           Telangana
# 15           Karnataka
# 16           Bengaluru
# 17                Pune
# 18            Kolhapur
# 19           Bengaluru
# 20             Chennai
# 21       Coimbatore[9]
# 22             Gurgaon
# 23           Hyderabad
# 24               Kochi
# 25             Kolkata
# 26       Mangalore[10]
# 27              Mumbai
# 28                Pune
# 29           Bengaluru
# 30             Gurgaon
# 31           Hyderabad
# 32              Mumbai
# 33             Kolkata
# 34                Pune
# 35             Chennai
# 36           Bengaluru
# 37           Hyderabad
# 38         Bhubaneswar
# 39             Kolkata
# 40              Mumbai
# 41             Madurai
# 42                Pune
# 43                Pune
# 44             Chennai
# 45           Bengaluru
# 46               Kochi
# 47              Mumbai
# 48               Noida
# 49           Bengaluru
# 50             Chennai
# 51           Hyderabad
# 52               Noida
# 53           Bengaluru
# 54           Ahmedabad
# 55           Bangalore
# 56             Chennai
# 57             Gurgaon
# 58           Hyderabad
# 59               Kochi
# 60             Kolkata
# 61              Mumbai
# 62           New Delhi
# 63               Noida
# 64           Bengaluru
# 65                 Goa
# 66           Hyderabad
# 67              Nagpur
# 68                Pune
# 69             Chennai
# 70              Mumbai
# 71              Mumbai
# 72               Noida
# 73           Bengaluru
# 74             Chennai
# 75                Pune
# 76           Bengaluru
# 77          Mumbai[12]
# 78           Bangalore
# 79              Mumbai
# 80                 NaN
# 81                 NaN
# 82                 NaN
# 83                 NaN
# 84                 NaN
# 85              Mumbai
# 86              Nashik
# 87           Hyderabad
# 88           Bengaluru
# 89              Mumbai
# 90                Pune
# 91           Bangalore
# 92             Chennai
# 93             Gurgaon
# 94             Lucknow
